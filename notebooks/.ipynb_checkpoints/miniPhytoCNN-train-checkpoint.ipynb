# %% [markdown]
# # Train your own Phytoplankton Classifier.
#
# `This notebook was developed for Eart119A in Spring25 by Patrick Daniel.`
#
# ## Goal
#
# Here we will train two different phytoplankton classifiers, a simple CNN and a then we are going to use __ResNet18__ and train one with Tranfer Learning.
#
# ### But First, Make sure you are using a GPU
#
# _If on colab:_
# Training greatly benefits from using "T4 GPU" so got up to the top right corner and click on the carrot. Select __Change Runtime Type__ and __select T4 GPU__.

# %% [markdown]
# ## Getting Training Data
#
#  This code below will pull the training data from a repo that I setup and unzip it into a directory called "training".
#
#  Open it up and look around, you should see 6 different directories that contain images of phytoplankton.

# %%
# prompt: Get a remote .zip file from https://git.ucsc.edu/pcdaniel/eart119a-ML-Lecture/-/blob/5704ab8e2acbe5363004460bdc94960422f8010a/phyto-mini/training.zip
# !wget https://git.ucsc.edu/pcdaniel/eart119a-ML-Lecture/-/raw/5704ab8e2acbe5363004460bdc94960422f8010a/phyto-mini/training.zip
# !unzip training.zip
# !rm -rf __MACOSX
# Out:
# --2025-06-10 16:41:21--  https://git.ucsc.edu/pcdaniel/eart119a-ML-Lecture/-/raw/5704ab8e2acbe5363004460bdc94960422f8010a/phyto-mini/training.zip
# Resolving git.ucsc.edu (git.ucsc.edu)... 169.233.8.13
# Connecting to git.ucsc.edu (git.ucsc.edu)|169.233.8.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67359597 (64M) [application/octet-stream]
# Saving to: ‘training.zip’
#
# training.zip        100%[===================>]  64.24M  38.4MB/s    in 1.7s
#
# 2025-06-10 16:41:25 (38.4 MB/s) - ‘training.zip’ saved [67359597/67359597]
#
# Archive:  training.zip
#    creating: training/
#   inflating: __MACOSX/._training
#   inflating: training/.DS_Store
#   inflating: __MACOSX/training/._.DS_Store
#    creating: training/Akashiwo/
#   inflating: __MACOSX/training/._Akashiwo
#    creating: training/Eucampia/
#   inflating: __MACOSX/training/._Eucampia
#    creating: training/Dinophysis/
#   inflating: __MACOSX/training/._Dinophysis
#    creating: training/Ceratium/
#   inflating: __MACOSX/training/._Ceratium
#  extracting: training/Akashiwo/D20200621T011836_IFCB104_01789.png
#   inflating: __MACOSX/training/Akashiwo/._D20200621T011836_IFCB104_01789.png
#  extracting: training/Akashiwo/D20161009T011724_IFCB104_00127.png
#   inflating: __MACOSX/training/Akashiwo/._D20161009T011724_IFCB104_00127.png
#  extracting: training/Akashiwo/D20161016T125202_IFCB104_00569.png
#   inflating: __MACOSX/training/Akashiwo/._D20161016T125202_IFCB104_00569.png
#  extracting: training/Akashiwo/D20240522T053458_IFCB161_01018.png
#   inflating: __MACOSX/training/Akashiwo/._D20240522T053458_IFCB161_01018.png
#  extracting: training/Akashiwo/D20151201T144015_IFCB104_00021.png
#   inflating: __MACOSX/training/Akashiwo/._D20151201T144015_IFCB104_00021.png
#  extracting: training/Akashiwo/D20151201T132912_IFCB104_00023.png
#   inflating: __MACOSX/training/Akashiwo/._D20151201T132912_IFCB104_00023.png
#  extracting: training/Akashiwo/D20240516T192641_IFCB161_01166.png
#   inflating: __MACOSX/training/Akashiwo/._D20240516T192641_IFCB161_01166.png
#  extracting: training/Akashiwo/D20151201T190217_IFCB104_00348.png
#   inflating: __MACOSX/training/Akashiwo/._D20151201
#  extracting: training/Dinophysis/D20160804T113035_IFCB104_00399.png
#  extracting: training/Dinophysis/D20181126T175917_IFCB104_00300.png
#  extracting: training/Dinophysis/D20160804T082106_IFCB104_00035.png
#  extracting: training/Dinophysis/D20170617T060039_IFCB104_00143.png
#  extracting: training/Dinophysis/D20210825T151229_IFCB104_00323.png
#  extracting: training/Dinophysis/D20240516T232413_IFCB161_01364.png
#  extracting: training/Dinophysis/D20240521T145615_IFCB161_00865.png
#  extracting: training/Dinophysis/D20160804T024932_IFCB104_00713.png
#  extracting: training/Dinophysis/D20160804T055900_IFCB104_00518.png
#  extracting: training/Dinophysis/D20240517T054415_IFCB161_01384.png
#  extracting: training/Dinophysis/D20240512T182610_IFCB161_00277.png
#  extracting: training/Dinophysis/D20160804T141621_IFCB104_00053.png
#  extracting: training/Dinophysis/D20181121T063143_IFCB104_00550.png
#  extracting: training/Dinophysis/D20240522T002615_IFCB161_00901.png
#  extracting: training/Dinophysis/D20161101T023858_IFCB104_00036.png
#  extracting: training/Dinophysis/D20240514T064553_IFCB161_01371.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_01578.png
#  extracting: training/Ceratium/D20191113T180511_IFCB113_00077.png
#   inflating: training/Ceratium/D20191113T183319_IFCB113_00855.png
#   inflating: training/Ceratium/D20191113T183319_IFCB113_01593.png
#  extracting: training/Ceratium/D20160804T031313_IFCB104_00885.png
#  extracting: training/Ceratium/D20180803T182200_IFCB113_02525.png
#  extracting: training/Ceratium/D20191113T221400_IFCB113_00209.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_00841.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_05087.png
#  extracting: training/Ceratium/D20180803T182200_IFCB113_00454.png
#  extracting: training/Ceratium/D20180207T183925_IFCB113_00827.png
#  extracting: training/Ceratium/D20190822T184205_IFCB113_00485.png
#  extracting: training/Ceratium/D20190822T184205_IFCB113_01943.png
#  extracting: training/Ceratium/D20181214T203414_IFCB113_00477.png
#   inflating: training/Ceratium/D20191113T183319_IFCB113_03145.png
#   inflating: training/Ceratium/D20191023T173145_IFCB113_00593.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_02529.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_05508.png
#  extracting: training/Ceratium/D20190822T184205_IFCB113_00888.png
#  extracting: training/Ceratium/D20180207T183925_IFCB113_01046.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_06773.png
#  extracting: training/Ceratium/D20160804T084448_IFCB104_00003.png
#  extracting: training/Ceratium/D20151201T033711_IFCB104_00219.png
#   inflating: training/Ceratium/D20191113T200737_IFCB113_00426.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_04831.png
#  extracting: training/Ceratium/D20181214T194033_IFCB113_02568.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_06940.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_07486.png
#  extracting: training/Ceratium/D20190822T184205_IFCB113_02912.png
#  extracting: training/Ceratium/D20180803T182200_IFCB113_00130.png
#   inflating: training/Ceratium/D20191113T183319_IFCB113_01975.png
#  extracting: training/Ceratium/D20190801T172929_IFCB113_00940.png
#  extracting: training/Ceratium/D20181214T203414_IFCB113_00675.png
#  extracting: training/Ceratium/D20190918T173033_IFCB113_02508.png
#  extracting: training/Ceratium/D20180918T174433_IFCB113_00965.png
#  extracting: training/Ceratium/D20190822T184205_IFCB113_02091.png
#  extracting: training/Ceratium/D20180918T172017_IFCB113_01465.png
#  extracting: training/Ceratium/D20180315T171851_IFCB113_01202.png
#  extracting: training/Ceratium/D20190822T184205_IFCB113_02085.png
#  extracting: training/Ceratium/D20191113T180511_IFCB113_00260.png
#  extracting: training/Ceratium/D20190822T184205_IFCB113_00862.png
#  extracting: training/Ceratium/D20180918T174433_IFCB113_02197.png
#  extracting: training/Ceratium/D20210825T151229_IFCB104_01389.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113
png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_01800.png
#  extracting: training/Ceratium/D20190822T184205_IFCB113_03589.png
#  extracting: training/Ceratium/D20151201T062256_IFCB104_00125.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_04950.png
#  extracting: training/Ceratium/D20181207T101633_IFCB104_00019.png
#  extracting: training/Ceratium/D20180918T174433_IFCB113_03464.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_07518.png
#  extracting: training/Ceratium/D20191205T205114_IFCB113_00037.png
#  extracting: training/Ceratium/D20210825T151229_IFCB104_01570.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_05469.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_04777.png
#   inflating: training/Ceratium/D20180720T184448_IFCB113_00300.png
#  extracting: training/Ceratium/D20180803T182200_IFCB113_02691.png
#   inflating: training/Ceratium/D20180918T174433_IFCB113_00637.png
#  extracting: training/Ceratium/D20160804T093210_IFCB104_00123.png
#   inflating: training/Ceratium/D20180517T161314_IFCB113_00259.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_03756.png
#  extracting: training/Ceratium/D20160804T022551_IFCB104_00227.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_01179.png
#  extracting: training/Ceratium/D20190822T184205_IFCB113_01359.png
#   inflating: training/Ceratium/D20181205T185642_IFCB113_00748.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_04767.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_03020.png
#  extracting: training/Ceratium/D20190822T184205_IFCB113_00709.png
#   inflating: training/Ceratium/D20191113T183319_IFCB113_01151.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_05337.png
#  extracting: training/Ceratium/D20180712T174830_IFCB113_02580.png
#  extracting: training/Ceratium/D20180207T181511_IFCB113_00223.png
#  extracting: training/Ceratium/D20191113T180511_IFCB113_00338.png
#  extracting: training/Ceratium/D20180919T163509_IFCB113_04060.png
#  extracting: training/Ceratium/D20190822T172704_IFCB113_00293.png
#  extracting: training/Ceratium/D20181214T194033_IFCB113_02431.png
#   inflating: training/Ceratium/D20190918T173033_IFCB113_01616.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_01192.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_00703.png
#  extracting: training/Ceratium/D20191113T183319_IFCB113_06372.png
#   inflating: training/Ceratium/D20191113T200737_IFCB113_00027.png
#  extracting: training/Ceratium/D20180803T185840_IFCB113_01117.png

# %% [markdown]
# ### Examining the Training Data ###
#
# Pytorch can load data pretty efficiently using __Data Loaders__. Before we start that, lets look at some of the images once that have been processed:

# %%
import os
import matplotlib.pyplot as plt
from torchvision.datasets import ImageFolder
from torchvision import transforms
from PIL import Image
import numpy as np

# Replace this with your dataset path
data_dir = "training"

# Transform to load images
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])

# Load dataset
dataset = ImageFolder(root=data_dir, transform=transform)
class_names = dataset.classes

# Count images per class
class_counts = {name: 0 for name in class_names}
for _, label in dataset.samples:
    class_name = class_names[label]
    class_counts[class_name] += 1

# Plot histogram
plt.figure(figsize=(8, 5))
plt.bar(class_counts.keys(), class_counts.values(), color='skyblue')
plt.title("Image Count per Class")
plt.xlabel("Class")
plt.ylabel("Number of Images")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("../figures/class_distribution_histogram.png")
plt.show()

# Create mosaic: 5 images from each class
fig, axs = plt.subplots(len(class_names), 5, figsize=(10, 2 * len(class_names)))
for row, class_name in enumerate(class_names):
    class_indices = [i for i, (_, label) in enumerate(dataset.samples) if dataset.classes[label] == class_name]
    for col, idx in enumerate(class_indices[:5]):
        img, _ = dataset[idx]
        axs[row, col].imshow(img.squeeze(), cmap='gray')
        axs[row, col].axis('off')
        if col == 0:
            axs[row, col].set_title(class_name, loc='left', fontsize=10)
plt.tight_layout()
plt.savefig("../figures/class_image_mosaic.png")
plt.show()

# %% [markdown]
# ## Now lets start the training. ##
#
# Run the cell below to train the "simple" model.
#
#
# It will go through __10 Epochs__ meaning the model will see all of the data 10 times. We can adjust this as neeeded, if the __Loss__ plateaus early.
#
# The __batch size__ corresponds to how many images we can feed to the model at once. This depends on how much vRAM the GPU has. If you can feed it more, it will train faster.
#
# The __transforms__ are the routines used to prepare the iamges for training. They will be:
# 1. Converted to greyscale (they actually aready are in greyscale, but we want it as one channel instead of RGB)
# 2. Resized into a smaller size to train faster (64x64 pxs)
# 3. Converted into a __Tensor__. This is basically a big matrix, efficient matrix.
# 4. Finally Images are normalized based on a mean and standard deviations. This value can depend on the data.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Settings
data_dir = "training"  # Update this path
batch_size = 64
num_epochs = 10
num_classes = 6
learning_rate = 0.001

# Transforms
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.485,), (0.228,))
])

# Load Dataset
dataset = datasets.ImageFolder(root=data_dir, transform=transform)
print(f"Number of images: {len(dataset)}")
# Out:
# Number of images: 2400

# %% [markdown]
# ## Train/Validation Split ##
#
# We want to reserve some of that data to be used for validating how well the model worked, so we will split it up into __train_set__ and __val_set__ at a ratio of 80:20.
#
# The model will never see the __validation__ set untill we are estimating statistics

# %%
# 80/20 Train/Validation split
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_set, val_set = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Defing the Model Structure ##
#
# We are first going to use a very simple CNN structure.

# %%
# Define CNN
class SmallCNN(nn.Module):
    def __init__(self):
        super(SmallCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(16 * 16 * 16, 64)
        self.fc2 = nn.Linear(64, num_classes)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))  # 64 → 32
        x = self.pool(torch.relu(self.conv2(x)))  # 32 → 16
        x = x.view(-1, 16 * 16 * 16)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# Now we want to make the model and ensure that it is running on a __GPU__.
#
# There are some other important parameters here like: `CrossEntropyLoss` which is our loss function and `Adam`, a very efficient stochaistic-gradient method.

# %%
# Training Setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model = SmallCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# Using device: cuda

# %% [markdown]
# ## Training ##
#
# The model is now ready to be trained! We are going to loop through each epoch (remember we said earlier that we want to see all of the images 10 times).
#
# During each Epoch we are going to get the __Loss__ value so that we can plot it and see how it changes over training.
#
# __Warning: This step might be a bit slow!__

# %%
# Training Loop
train_loss_list = []
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    epoch_loss = running_loss / len(train_loader)
    train_loss_list.append(epoch_loss)
    print(f"Epoch {epoch+1}/{num_epochs} - Loss: {epoch_loss:.4f}")

# Plot Training Loss
plt.plot(train_loss_list)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.grid(True)
plt.show()
# Out:
# Epoch 1/10 - Loss: 1.3856
# Epoch 2/10 - Loss: 0.4386
# Epoch 3/10 - Loss: 0.2805
# Epoch 4/10 - Loss: 0.2104
# Epoch 5/10 - Loss: 0.1610
# Epoch 6/10 - Loss: 0.1369
# Epoch 7/10 - Loss: 0.1044
# Epoch 8/10 - Loss: 0.0914
# Epoch 9/10 - Loss: 0.0737
# Epoch 10/10 - Loss: 0.0702

# %% [markdown]
# ## Now Let's Evaluate the Model Performance ##
#
# Remember that we saved 20% of the images for validation.
#
# Let's calculate some of those statistics

# %%
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Metrics
acc = accuracy_score(all_labels, all_preds)
f1 = f1_score(all_labels, all_preds, average='weighted')
cm = confusion_matrix(all_labels, all_preds, normalize='pred')

print(f"Accuracy: {acc:.3f}")
print(f"F1 Score (weighted): {f1:.3f}")

# Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=dataset.classes)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accuracy: 0.952
# F1 Score (weighted): 0.952

# %% [markdown]
# ## Now train a model using the ResNet18 Architecture ##
#
# ResNet 18 now has 18 layers, but it uses some special tricks that make it incredibly efficient.
#
# __We are also going to use the pre-trained model weights__. So the feature extraction should already be pretty good at distinguishing things for us.

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

# Settings
data_dir = "training"  # Update this path
batch_size = 450
num_epochs = 15
num_classes = 6
learning_rate = 0.001

best_val_loss = float('inf')
patience = 3
patience_counter = 0

os.makedirs("../model", exist_ok=True)
checkpoint_path = "../model/resnet18-6class-best.pth"


# Transforms for ResNet (ImageNet compatible)
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.489), (0.225))
])

# Load Dataset
dataset = datasets.ImageFolder(root=data_dir, transform=transform)

# 80/20 Train/Validation split
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_set, val_set = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)

# Load Pretrained ResNet18 and use transfer learning
model = models.resnet18(weights=True)

# Modify first conv layer for grayscale input
# Resnet normally acceptys 3-channel RGB
model.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)

# Modify final FC layer for 6 classes (instead of the 1000 used by ImageNet)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, num_classes)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)


train_loss_list = []
val_loss_list = []

for epoch in range(num_epochs):
    model.train()
    running_train_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_train_loss += loss.item()
    epoch_train_loss = running_train_loss / len(train_loader)
    train_loss_list.append(epoch_train_loss)

    # --- Validation ---
    model.eval()
    running_val_loss = 0.0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()
    epoch_val_loss = running_val_loss / len(val_loader)
    val_loss_list.append(epoch_val_loss)

    print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {epoch_train_loss:.4f} - Val Loss: {epoch_val_loss:.4f}")

    # --- Checkpoint ---
    if epoch_val_loss < best_val_loss:
        print("Validation loss improved. Saving model...")
        best_val_loss = epoch_val_loss
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_loss': best_val_loss
        }, checkpoint_path)
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break
# Out:
# Epoch 1/15 - Train Loss: 0.5030 - Val Loss: 4.8088
# Validation loss improved. Saving model...
# Epoch 2/15 - Train Loss: 0.0762 - Val Loss: 2.0643
# Validation loss improved. Saving model...
# Epoch 3/15 - Train Loss: 0.0234 - Val Loss: 1.6868
# Validation loss improved. Saving model...
# Epoch 4/15 - Train Loss: 0.0157 - Val Loss: 1.2941
# Validation loss improved. Saving model...
# Epoch 5/15 - Train Loss: 0.0060 - Val Loss: 1.2406
# Validation loss improved. Saving model...
# Epoch 6/15 - Train Loss: 0.0021 - Val Loss: 0.5902
# Validation loss improved. Saving model...
# Epoch 7/15 - Train Loss: 0.0013 - Val Loss: 0.1610
# Validation loss improved. Saving model...
# Epoch 8/15 - Train Loss: 0.0015 - Val Loss: 0.0749
# Validation loss improved. Saving model...
# Epoch 9/15 - Train Loss: 0.0005 - Val Loss: 0.1495
# Epoch 10/15 - Train Loss: 0.0057 - Val Loss: 0.0148
# Validation loss improved. Saving model...
# Epoch 11/15 - Train Loss: 0.0165 - Val Loss: 0.0578
# Epoch 12/15 - Train Loss: 0.0031 - Val Loss: 0.1512
# Epoch 13/15 - Train Loss: 0.0043 - Val Loss: 0.0105
# Validation loss improved. Saving model...
# Epoch 14/15 - Train Loss: 0.0018 - Val Loss: 0.0180
# Epoch 15/15 - Train Loss: 0.0010 - Val Loss: 0.0211

# %%
# Evaluation
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Metrics
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
acc = accuracy_score(all_labels, all_preds)
f1 = f1_score(all_labels, all_preds, average='weighted')

cm = confusion_matrix(all_labels, all_preds,normalize="true")

# Calculate per-class accuracy
class_counts = np.sum(cm, axis=1)
correct_preds = np.diag(cm)
per_class_accuracy = correct_preds / class_counts
# Weighted accuracy
weighted_acc = np.sum(per_class_accuracy * (class_counts / np.sum(class_counts)))



print(f"Accuracy: {acc:.3f}")
print(f"F1 Score (weighted): {f1:.3f}")
print(f"Weighted Accuracy: {weighted_acc:.3f}")

# Classification Report
class_names = dataset.classes
class_indices = list(range(len(class_names)))

cr = classification_report(np.array(all_labels), np.array(all_preds),labels=class_indices, target_names=class_names, zero_division=0)
print(cr)
with open("../model/classification_report.txt", "w") as f:
    f.write(cr)

# Confusion Matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=dataset.classes)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix (ResNet18)")
plt.savefig("../figures/ConfusionMatrix_resnet18.png",bbox_inches='tight')
plt.show()

# Plot Training Loss
plt.semilogy(train_loss_list,label="Training Loss")
plt.semilogy(val_loss_list,label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss (ResNet18)")
plt.legend()

plt.grid(True)
plt.savefig("../figures/training_loss.png",bbox_inches='tight')
# Out:
# Accuracy: 0.992
# F1 Score (weighted): 0.992
# Weighted Accuracy: 0.991
#               precision    recall  f1-score   support
#
#     Akashiwo       0.95      1.00      0.98        79
#     Ceratium       1.00      1.00      1.00        86
#   Dinophysis       1.00      0.96      0.98        72
#     Eucampia       1.00      1.00      1.00        83
#       Laboea       1.00      1.00      1.00        80
# Prorocentrum       1.00      0.99      0.99        80
#
#     accuracy                           0.99       480
#    macro avg       0.99      0.99      0.99       480
# weighted avg       0.99      0.99      0.99       480

# %% [markdown]
# ### Print the total number of Paramaters in the model

# %%
total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Total trainable parameters: {total_params}")
# Out:
# Total trainable parameters: 11173318

# %% [markdown]
# ### Save the final Trained Model

# %%
# Save path
save_path = "../model/resnet18-6class.pth"

# Get the class-to-index mapping from the dataset
class_to_idx = dataset.class_to_idx

# Create a checkpoint dictionary
checkpoint = {
    'model_state_dict': model.state_dict(),     # weights
    'model_arch': 'resnet18',                   # structure hint
    'num_classes': num_classes,
    'class_to_idx': class_to_idx,
    'input_channels': 1                         # since we modified conv1
}

# Save it
torch.save(checkpoint, save_path)
print(f"Model saved to {save_path}")
# Out:
# Model saved to ../model/resnet18-6class.pth
